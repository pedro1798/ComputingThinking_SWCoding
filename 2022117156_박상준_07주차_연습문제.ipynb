# %% [markdown]
# # 2022117156_박상준_-07주차_연습문제
# > https://github.com/pedro1798

# %%
### 문제1 : 
    
<pre><code>
import random as r
romio = r.randrange(1, 7)
juliett = r.randrange(1, 7)
if romio > juliett:
    print(f"로미오의 주사위 숫자는 {romio} 입니다.\n줄리엣의 주사위 숫자는 {juliett} 입니다.\n로미오가 이겼습니다.")
elif romio < juliett:
    print(f"로미오의 주사위 숫자는 {romio} 입니다.\n줄리엣의 주사위 숫자는 {juliett} 입니다.\n줄리엣이 이겼습니다.")
else:
    print(f"로미오의 주사위 숫자는 {romio} 입니다.\n줄리엣의 주사위 숫자는 {juliett} 입니다.\n동점 입니다.")
</code></pre>

### 문제 2 : 
    
<pre><code>
import random as r

rand = r.randrange(1, 21)
num = 1

while 1:
    i = int(input("1~20까지의 숫자를 입력하세요 : "))
    if rand < i:
        print(f"{i}보다 작습니다!")
        num += 1
    elif rand > i:
        print(f"{i}보다 큽니다!")
        num += 1
    else:
        if num <= 3:
            print(f"{num}번 만에 맞춘 당신은 천재!")
            break;
        elif num <= 6:
            print(f"{n}번 만에 맞추셨네요. 잘 했어요^^")
            break;
        else:
            print(f"{num}번 만에 맞추다니 쩝쩝...")
            break
</code></pre>

### 문제 3 :
    
<pre><code>
import turtle as t
t.left(180)
t.pensize(3)
for i in range(4):
    t.circle(50)
    t.penup()
    t.forward(80)
    t.pendown()
t.done()
</code></pre>

<pre><code>
import turtle as t
t.penup()
t.forward(-125)
t.pendown()

t.pensize(8)
index = 0
color = ["blue", "yellow", "black", "green", "red"]
for i in range(5):
    t.pencolor(color[index])
    index += 1
    t.circle(60)
    t.penup()
    t.forward(70)
    t.pendown()

    x = t.xcor()
    y = t.ycor()
    if index % 2 == 1:
        t.penup()
        t.setpos(x,y-50)
        t.pendown()
    else:
        t.penup()
        t.setpos(x,y+50)
        t.pendown()
t.done()
</code></pre>

### 문제 4 : 

<pre><code>
import turtle as t
x = -200
y = 200
t.speed(0)
index = 0
t.penup()
t.setpos(x, y) # -200, 200
t.pendown()
a = "white"
b = "black"
for i in range(8):
    for i in range(8):
        t.penup()
        t.setpos(x, y)
        t.pendown()
        if index==0:
            t.color(a)
        else:
            t.color(b)
        t.begin_fill()
        for i in range(4):
            t.forward(50)
            t.right(90)
        t.end_fill()
        index = (index + 1) % 2
        x += 50
    x = -200
    y -= 50
    a, b = b, a

t.color("black")
t.penup()
t.setpos(-200, 200)
t.pendown()
t.pensize(3)
for i in range(4):
    t.forward(400)
    t.right(90)
t.done()
</code></pre>

### 문제 5 :

(1)
<pre><code>
import math as m
for i in range(1,272,30):
    print(f"log({i:>3}) = {m.log(i):.3f}")
</code></pre>

### 문제 6 :
<pre><code>
import datetime as dt
start = dt.datetime(2019, 2, 24)
time_gap = dt.datetime.now() - start
print(time_gap)
print(f"오늘은 {dt.datetime.today().year}년 {dt.datetime.today().month}월 {dt.datetime.today().day}일입니다.")
print("춘향이와 몽룡이의 연애 시작일 : 2019년 2월 24일")
print(f"연애 시작일로부터 경과한 날짜 : {time_gap.days}일")
a = dt.timedelta(days = 100)
b = start + a
print(f"100일 기념일 : {b.year}년 {b.month}월 {b.year}일")
a = dt.timedelta(days = 200)
b = start + a
print(f"200일 기념일 : {b.year}년 {b.month}월 {b.year}일")
a = dt.timedelta(days = 500)
b = start + a
print(f"500일 기념일 : {b.year}년 {b.month}월 {b.year}일")
a = dt.timedelta(days = 1000)
b = start + a
print(f"1000일 기념일 : {b.year}년 {b.month}월 {b.year}일")
</code></pre>

<pre><code></code></pre>

<pre><code></code></pre>
